# %%
#libraries we need
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import date
pd.options.mode.chained_assignment = None
import h2o
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

#libraries we need
# !pip install h2o

from scipy.special import expit
from h2o.estimators.glm import H2OGeneralizedLinearEstimator
from h2o.grid.grid_search import H2OGridSearch
from sklearn import preprocessing

from sklearn.model_selection import train_test_split
from h2o.estimators import H2OGradientBoostingEstimator
SEED  = 1111   # global random seed for better reproducibility

from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

# conda install -c conda-forge pydotplus

h2o.init(max_mem_size='24G', nthreads=4) # start h2o with plenty of memory and threads
h2o.remove_all()                         # clears h2o memory
h2o.no_progress()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "1.8.0_152-release"; OpenJDK Runtime Environment (build 1.8.0_152-release-1056-b12); OpenJDK 64-Bit Server VM (build 25.152-b12, mixed mode)
#   Starting server from /Applications/Utilities/anaconda3/lib/python3.7/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /var/folders/rz/q545n5f15gz3jyrtnk4qt5l00000gn/T/tmpigfn09ve
#   JVM stdout: /var/folders/rz/q545n5f15gz3jyrtnk4qt5l00000gn/T/tmpigfn09ve/h2o_zhangmaojn_started_from_python.out
#   JVM stderr: /var/folders/rz/q545n5f15gz3jyrtnk4qt5l00000gn/T/tmpigfn09ve/h2o_zhangmaojn_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         03 secs
# ...

# %%
train = pd.read_csv('adult.data.txt',
                    names=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','class'])

# %%
test = pd.read_csv('adult.test.txt',
                    names=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','class'])

# %%
train.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country   class
# 0          2174             0              40   United-States   <=50K
# ...

# %%
train.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# class             object
# dtype: object

# %%
train.shape
# Out:
# (32561, 15)

# %%
test
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 0       25        Private  226802           11th              7
# 1       38        Private   89814        HS-grad              9
# 2       28      Local-gov  336951     Assoc-acdm             12
# 3       44        Private  160323   Some-college             10
# 4       18              ?  103497   Some-college             10
# ...    ...            ...     ...            ...            ...
# 16276   39        Private  215419      Bachelors             13
# 16277   64              ?  321403        HS-grad              9
# 16278   38        Private  374983      Bachelors             13
# 16279   44        Private   83891      Bachelors             13
# 16280   35   Self-emp-inc  182148      Bachelors             13
#
#             marital-status          occupation     relationship  \
# 0            Never-married   Machine-op-inspct        Own-child
# 1       Married-civ-spouse     Farming-fishing          Husband
# ...

# %% [raw]
# cc = [key for key in dict(train.dtypes) if dict(train.dtypes)[key] in ['float64', 'int64']]
# obj = [key for key in dict(train.dtypes) if dict(train.dtypes)[key] in ['object']]
#
# for i in obj:
#     print(train[i].value_counts())

# %%
## USE THE ABOVE TO REMOVE THE '?'

# %% [raw]
# for i in obj:
#     print(train[i].unique())

# %% [markdown]
# Replace all entries that contains ? with Null

# %%
train=train.replace(' ?', np.nan)

test=test.replace(' ?', np.nan)

# %% [markdown]
# Fill Null with 'None' type

# %%
train.update(train[['native-country','occupation','workclass']].fillna('None'))
test.update(test[['native-country','occupation','workclass']].fillna('None'))

# %%
train.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# class             0
# dtype: int64

# %%
test.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# class             0
# dtype: int64

# %% [markdown]
# train.head()

# %% [markdown]
# test.head()

# %%
train.to_csv('train.csv',index=False)

# %%
test.to_csv('test.csv',index=False)

# %% [markdown]
# ## GLM

# %% [markdown]
# GLM can produce two categories of models: classification and regression.
#
# Logistic regression is the GLM performing binary classification.

# %%
hf=h2o.H2OFrame(train)
gf=h2o.H2OFrame(test)

# %%
response_col = 'class'
predictors = list(train.columns.values)
predictors.remove('class')

# %%
glm_model = H2OGeneralizedLinearEstimator(family= "binomial",
                                          lambda_ = 0,
                                          compute_p_values = True,remove_collinear_columns=True)
glm_model.train(predictors, response_col, training_frame= hf,validation_frame=gf)

# %%
glm_model.std_coef_plot()

# %%
glm_model
# Out:
# Model Details
# ...
# H2OGeneralizedLinearEstimator :  Generalized Linear Modeling
# Model Key:  GLM_model_python_1594924018713_1
#
#
# GLM Model: summary
#        family   link regularization  number_of_predictors_total  \
# 0    binomial  logit           None                         100
#
#   number_of_active_predictors  number_of_iterations  \
# 0                          98                     8
#
#                                            training_frame
# 0  Key_Frame__upload_abeecb6adaf93e98951c806cbbf24286.hex
# ModelMetricsBinomialGLM: glm
# ** Reported on train data. **
#
# MSE: 0.10106348033611579
# RMSE: 0.31790482905441336
# LogLoss: 0.31579234496813513
# Null degrees of freedom: 32560
# Residual degrees of freedom: 32462
# Null deviance: 35948.079435207605
# Residual deviance: 20565.029089014897
# AIC: 20763.029089014897
# AUC: 0.9088752373735435
# AUCPR: 0.7712473241115264
# Gini: 0.817750474747087
#
# ...

# %% [markdown]
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.35971235775242977:
#
#
# Gains/Lift Table: Avg response rate: 23.62 %, avg score: 30.20 %
#
#
# AUC: 0.9043290738465083

# %%
glm_pred = glm_model.predict(gf)
glm_pred
# Out:
# <table>
# <thead>
# <tr><th>predict  </th><th style="text-align: right;">   &lt;=50K</th><th style="text-align: right;">      &gt;50K</th><th style="text-align: right;">  StdErr</th></tr>
# </thead>
# <tbody>
# <tr><td>&lt;=50K    </td><td style="text-align: right;">0.99773 </td><td style="text-align: right;">0.00226997</td><td style="text-align: right;">0.231683</td></tr>
# <tr><td>&lt;=50K    </td><td style="text-align: right;">0.881624</td><td style="text-align: right;">0.118376  </td><td style="text-align: right;">0.127049</td></tr>
# <tr><td>&gt;50K     </td><td style="text-align: right;">0.616993</td><td style="text-align: right;">0.383007  </td><td style="text-align: right;">0.142552</td></tr>
# <tr><td>&gt;50K     </td><td style="text-align: right;">0.22624 </td><td style="text-align: right;">0.77376   </td><td style="text-align: right;">0.133312</td></tr>
# ...

# %%
predictions = glm_pred.as_data_frame()
# Create the pandas DataFrame

# %%
predictions = predictions.drop(['predict',' <=50K','StdErr'],axis=1)

# %%
predictions['glm']=predictions[' >50K']
predictions=predictions.drop([' >50K'],axis =1)

# %% [markdown]
# ## GLM WITH HYPERPARAMETERS

# %%
# Example of values to grid over for `lambda`
# import Grid Search

hyper_params = {'lambda': [1, 0.5, 0.1, 0.01, 0.001, 0.0001, 0.00001, 0]}


glm = H2OGeneralizedLinearEstimator(family = 'binomial',remove_collinear_columns=True)

grid = H2OGridSearch(model = glm, hyper_params = hyper_params,
                     search_criteria = {'strategy': "Cartesian"})

grid.train(x = predictors, y = response_col, training_frame = hf, validation_frame = gf,nfolds=5,seed=1)

# %%
grid_table = grid.get_grid(sort_by = 'auc', decreasing = True)
grid_table
# Out:
#        lambda  \
# 0    [1.0E-5]
# 1    [1.0E-4]
# 2       [0.0]
# 3     [0.001]
# 4      [0.01]
# 5       [0.1]
# 6       [1.0]
# 7       [0.5]
#
#                                                                model_ids  \
# 0  Grid_GLM_Key_Frame__upload_abeecb6adaf93e98951c806cbbf24286.hex_mo...
# 1  Grid_GLM_Key_Frame__upload_abeecb6adaf93e98951c806cbbf24286.hex_mo...
# 2  Grid_GLM_Key_Frame__upload_abeecb6adaf93e98951c806cbbf24286.hex_mo...
# 3  Grid_GLM_Key_Frame__upload_abeecb6adaf93e98951c806cbbf24286.hex_mo...
# 4  Grid_GLM_Key_Frame__upload_abeecb6adaf93e98951c806cbbf24286.hex_mo...
# 5  Grid_GLM_Key_Frame__upload_abeecb6adaf93e98951c806cbbf24286.hex_mo...
# 6  Grid_GLM_Key_Frame__upload_abeecb6adaf93e98951c806cbbf24286.hex_mo...
# 7  Grid_GLM_Key_Frame__upload_abeecb6adaf93e98951c806cbbf24286.hex_mo...
#
#                    auc
# 0   0.9066975737235484
# 1   0.9064584331633282
# 2   0.9064227394258625
# 3   0.9035353644790536
# 4   0.8979830368459872
# ...

# %%
best = grid_table.models[0]
print(best.actual_params['lambda'])
# Out:
# [1e-05]

# %%
best
# Out:
# Model Details
# ...
# H2OGeneralizedLinearEstimator :  Generalized Linear Modeling
# Model Key:  Grid_GLM_Key_Frame__upload_abeecb6adaf93e98951c806cbbf24286.hex_model_python_1594924018713_4_model_7
#
#
# GLM Model: summary
#        family   link                               regularization  \
# 0    binomial  logit  Elastic Net (alpha = 0.5, lambda = 1.0E-5 )
#
#    number_of_predictors_total number_of_active_predictors  \
# 0                         108                          96
#
#    number_of_iterations  \
# 0                     4
#
#                                            training_frame
# 0  Key_Frame__upload_abeecb6adaf93e98951c806cbbf24286.hex
# ModelMetricsBinomialGLM: glm
# ** Reported on train data. **
#
# MSE: 0.10109197433481242
# RMSE: 0.31794964119308644
# LogLoss: 0.3159521864765541
# Null degrees of freedom: 32560
# Residual degrees of freedom: 32464
# Null deviance: 35948.079435207605
# Residual deviance: 20575.43828772615
# AIC: 20769.43828772615
# ...

# %%
best.varimp_plot()

# %%
best.predict(gf)
# Out:
# <table>
# <thead>
# <tr><th>predict  </th><th style="text-align: right;">   &lt;=50K</th><th style="text-align: right;">      &gt;50K</th></tr>
# </thead>
# <tbody>
# <tr><td>&lt;=50K    </td><td style="text-align: right;">0.997053</td><td style="text-align: right;">0.00294736</td></tr>
# <tr><td>&lt;=50K    </td><td style="text-align: right;">0.881809</td><td style="text-align: right;">0.118191  </td></tr>
# <tr><td>&gt;50K     </td><td style="text-align: right;">0.615354</td><td style="text-align: right;">0.384646  </td></tr>
# <tr><td>&gt;50K     </td><td style="text-align: right;">0.245103</td><td style="text-align: right;">0.754897  </td></tr>
# <tr><td>&lt;=50K    </td><td style="text-align: right;">0.99836 </td><td style="text-align: right;">0.00164031</td></tr>
# <tr><td>&lt;=50K    </td><td style="text-align: right;">0.995252</td><td style="text-align: right;">0.00474843</td></tr>
# ...

# %%
x = best.predict(gf)
x=x.as_data_frame()
x=x[' >50K']
predictions['glm_hyp']=x

# %% [markdown]
# AUC: 0.9066950328309124

# %% [markdown]
# ## GBM

# %% [markdown]
# #### PRE-PROCESSING FOR GBM

# %%
ss = hf.split_frame(seed = 1)
train_hf = ss[0]
valid_hf = ss[1]

# %%
gbm = H2OGradientBoostingEstimator(nfolds=5,
                                        seed=1111,
                                        keep_cross_validation_predictions = True)
gbm.train(x=predictors, y=response_col, training_frame=hf)

# Eval performance:
perf = gbm.model_performance(gf)

# Generate predictions on a test set:
gbm_pred = gbm.predict(gf)

# %%
gbm.model_performance(gf)
# Out:
# ModelMetricsBinomial: gbm
# ** Reported on test data. **
#
# MSE: 0.09033907842424388
# RMSE: 0.30056459941956554
# LogLoss: 0.2885572457637678
# Mean Per-Class Error: 0.16016157654750096
# AUC: 0.9234384268816671
# AUCPR: 0.8176605598174321
# Gini: 0.8468768537633342
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.29262006582812056:
#              <=50K    >50K   Error               Rate
# 0   <=50K  10688.0  1747.0  0.1405   (1747.0/12435.0)
# 1    >50K    728.0  3118.0  0.1893     (728.0/3846.0)
# 2   Total  11416.0  4865.0   0.152   (2475.0/16281.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.292620      0.715876  228.0
# 1                        max f2   0.184677      0.801689  272.0
# 2                  max f0point5   0.570050      0.757417  131.0
# 3                  max accuracy   0.503043      0.872428  153.0
# ...

# %%
gbm.varimp_plot()

# %%
x = gbm.predict(gf)
x=x.as_data_frame()
x=x[' >50K']
predictions['gbm']=x

# %% [markdown]
# AUC: 0.9234384268816671

# %% [markdown]
# ## XGBoost

# %%
from h2o.estimators import H2OXGBoostEstimator
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         37 secs
# H2O_cluster_timezone:       America/New_York
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.30.0.5
# H2O_cluster_version_age:    27 days
# H2O_cluster_name:           H2O_from_python_zhangmaojn_pv3baz
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    21.18 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.7.3 final
# ...

# %%
# Build and train the model:
xgb = H2OXGBoostEstimator(booster='dart',
                                  normalize_type="tree",
                                  seed=1234)
xgb.train(x=predictors,
                  y=response_col,
                  training_frame=train_hf,
                  validation_frame=valid_hf)

# %%
# Eval performance:
xgb.model_performance(gf)
# Out:
# ModelMetricsBinomial: xgboost
# ** Reported on test data. **
#
# MSE: 0.08752865128134162
# RMSE: 0.29585241469581014
# LogLoss: 0.2754554443836803
# Mean Per-Class Error: 0.15473629801645628
# AUC: 0.9280555090317806
# AUCPR: 0.8264562170678743
# Gini: 0.8561110180635612
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.3006711637973785:
#              <=50K    >50K   Error               Rate
# 0   <=50K  10726.0  1709.0  0.1374   (1709.0/12435.0)
# 1    >50K    686.0  3160.0  0.1784     (686.0/3846.0)
# 2   Total  11412.0  4869.0  0.1471   (2395.0/16281.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.300671      0.725186  227.0
# 1                        max f2   0.159961      0.808360  285.0
# 2                  max f0point5   0.664160      0.761383  105.0
# 3                  max accuracy   0.526798      0.874455  150.0
# ...

# %%
# Generate predictions on a test set (if necessary):
xgb_pred = xgb.predict(gf)

# %% [raw]
# params = {'learn_rate': [0.01, 0.05, 0.1],
#           'ntrees': [50, 80, 110, 140],
#           'sample_rate': [0.6,0.7,0.9],
#           'col_sample_rate': [0.3,0.5,0.6,0.8,1],
#           'max_depth': list(range(3,30,4))
# }
#
#
# # Prepare the grid object
# grid = H2OGridSearch(model=xgb,   # Model to be trained
#                      grid_id='grid',
#                      hyper_params=params,              # Dictionary of parameters
#                      search_criteria={"strategy": "RandomDiscrete"}   # RandomDiscrete
#                      )
#
# # Train the Model
# grid.train(x=predictors,y=response_col,
#            training_frame=train_hf,
#            validation_frame=valid_hf,
#            seed = 1111) # Grid Search ID

# %%
xgb.varimp_plot()

# %%
x = xgb.predict(gf)
x=x.as_data_frame()
x=x[' >50K']
predictions['xgb']=x

# %% [markdown]
# ## SURROGATE MODEL

# %%
from sklearn.tree import DecisionTreeRegressor,tree
dt = DecisionTreeRegressor(max_depth=10, min_samples_leaf=0.04,
random_state=SEED)

# %%
test_x_dummies = pd.get_dummies(test.drop(['class'],axis=1))
dt = dt.fit(test_x_dummies,predictions['xgb'])
dt.score(test_x_dummies,predictions['xgb'])
# Out:
# 0.6504061399540648

# %%
feature_cols = list(test_x_dummies.columns.values)

dot_data = StringIO()
export_graphviz(dt, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# ## Model Comparison

# %% [markdown]
# Plotting the residual values against the predicted values is a time-honored model assessment technique and a great way to see all your modeling results in two dimensions.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Give actual class lables:
#
# * <=50 -- 0
# * \>50 -- 1

# %%
class_dict = {0:'<=50K', 1:'>50K'}

# %%
test['label'] = pd.factorize(test['class'])[0]
train['label'] = pd.factorize(train['class'])[0]

# %%
predictions['actual']=test['label']

# %%
predictions=predictions.sort_values(by=['actual'])
predictions.head()
# Out:
#             glm   glm_hyp       gbm       xgb  actual
# 0      0.002270  0.002947  0.013364  0.001466       0
# 10112  0.070531  0.071753  0.129012  0.056514       0
# 10113  0.050879  0.051989  0.023922  0.013668       0
# 10115  0.161932  0.163608  0.030591  0.033277       0
# 10116  0.094219  0.095853  0.085771  0.081020       0

# %% [markdown]
# #### GLM Plot

# %%
fig, ax = plt.subplots(figsize=(20, 10)) 
sns.set_style('whitegrid') 
test_sub = predictions.reset_index()
values = list(test_sub.index)


ax.scatter(values,predictions['glm_hyp'],color='orange')
ax.scatter(values,predictions['actual'],color='Red')
plt.show()

# %% [markdown]
# #### GBM Plot

# %%
fig, ax = plt.subplots(figsize=(20, 10)) 
sns.set_style('whitegrid') 
test_sub = predictions.reset_index()
ax.scatter(values,predictions['gbm'],color='Green')
ax.scatter(values,predictions['actual'],color='Red')
plt.show()

# %% [markdown]
# #### XGB Plot

# %%
fig, ax = plt.subplots(figsize=(20, 10)) 
sns.set_style('whitegrid') 
test_sub = predictions.reset_index()
ax.scatter(values,predictions['xgb'],color='Silver')
ax.scatter(values,predictions['actual'],color='Red')
plt.show()

# %% [markdown]
# ### SHAP

# %%
contributions = xgb.predict_contributions(gf)
import shap
shap.initjs()
#contributions_matrix = contributions.as_data_frame().as_matrix()
#commendto run for Sally
contributions_matrix = contributions.as_data_frame().values

shap_values = contributions_matrix[:,:]
shap_values.shape


expected_value = contributions_matrix[:,:].min()
expected_value

shap.summary_plot(shap_values, contributions.col_names)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
pd.DataFrame(shap_values).head()

# %%
shap.summary_plot(shap_values, contributions.col_names, plot_type="bar")

# %%
shap.force_plot(expected_value, shap_values[1090,:], contributions.col_names, link='logit')

# %% [markdown]
# Visualizing for all predictoer, 500 samples

# %%
shap.force_plot(expected_value, shap_values[:50,:], contributions.col_names, link='logit')

# %% [markdown]
# #### Decision Plots: OUTLIERS - Capital Gain & Capital Loss

# %% [markdown]
# Reference: https://slundberg.github.io/shap/notebooks/plots/decision_plot.html

# %%
shap.decision_plot(expected_value, shap_values[:200,:], contributions.col_names, link='logit')

# %% [markdown]
# ### PARTIAL DEPENDENCE

# %%
dd = ['age','education-num','hours-per-week','capital-gain','capital-loss']

# %%
for i in dd:
    print(xgb.partial_plot(data = hf, cols = [i], server=True, plot = True))

# %% [markdown]
# # TRY TO COMBINE PD AND ICE

# %% [markdown]
# ## ICE????
# https://resources.oreilly.com/oriole/interpretable-machine-learning-with-python-xgboost-and-h2o/blob/master/xgboost_pdp_ice.ipynb

# %% [markdown]
# http://savvastjortjoglou.com/intrepretable-machine-learning-nfl-combine.html#PDP-and-ICE-plots

# %% [markdown]
# ## DISCRIMINATION TESTING

# %%
from rmltk import explain,debug, evaluate, model # simple module for evaluating, debugging, and training models

# %%
predict = h2o.as_list(xgb.predict(gf)[' >50K'])
#predict['label'] = train['label']

predict = pd.concat([predict, train], axis=1).rename(columns={" >50K": "prediction", "label": "actual"})

# %%
from rmltk import debug, evaluate, model # simple module for evaluating, debugging, and training models

# %% [markdown]
# ## YOUDEN CRITERIA FOR BEST F1 SCORE

# %%
j_frame = evaluate.get_youdens_j(predict,'actual','prediction')
best_cut = j_frame.loc[j_frame['J'].idxmax(), 'cutoff'] # Find cutoff w/ max F1

print('%.2f' % best_cut)

# %%
from sklearn.metrics import roc_auc_score
y_true = np.array([0, 0, 1, 1])
y_scores = np.array([0.1, 0.4, 0.35, 0.8])
roc_auc_score(y_true, y_scores)

# %% [markdown]
# ## DISCRIMINATION TESTING
#
# ### SEX

# %%
evaluate.get_confusion_matrix(predict,'actual','prediction', cutoff=best_cut)

# %%
sex_levels = list(predict['sex'].unique())
sex_levels

# %% [markdown]
# ###### Confusion matrix for SEX = male

# %%
male_cm = evaluate.get_confusion_matrix(predict,'actual','prediction', by='sex', level=' Male', cutoff=best_cut)
male_cm

# %% [markdown]
# ###### Confusion matrix for SEX = female

# %%
female_cm = evaluate.get_confusion_matrix(predict,'actual','prediction', by='sex', level=' Female', cutoff=best_cut)
female_cm

# %% [markdown]
# ### Disparate Accuracies and Errors

# %%
cm_dict = {'male': male_cm, 'female': female_cm} # group fairness metrics are based on confusion matrices
metrics_frame, disp_frame = debug.get_metrics_ratios(cm_dict, 'male') # calculate metrics and ratios
metrics_frame # display results

# %% [markdown]
# ### Calculate and report disparity

# %%
parity_threshold_low = 0.8    # user-defined low threshold value
parity_threshold_hi = 1.25   # user-defined high threshold value

#4/5 rule

# small utility function to format pandas table output
def disparate_red(val):
    
    color = 'blue' if (parity_threshold_low < val < parity_threshold_hi) else 'red'
    return 'color: %s' % color 

# display results
disp_frame.style.applymap(disparate_red)

# %% [markdown]
# ### Plot Prevalence Ratio Disparity

# %%
ax = disp_frame['Prevalence Ratio'].plot(kind='bar', color='b', title='Prevalence Ratio')
_ = ax.axhline(parity_threshold_low, color='r', linestyle='--')
_ = ax.axhline(parity_threshold_hi, color='r', linestyle='--')

# %% [markdown]
# ### Adverse Impact Ratio

# %%
print('Adverse impact ratio: %.3f' % debug.air(cm_dict, 'male', 'female'))

# %% [markdown]
# ### Marginal effect

# %%
print('Marginal effect: %.2f%%' % debug.marginal_effect(cm_dict, 'male', 'female'))

# %% [markdown]
# ### Standardized Mean Difference

# %%
print('Standardized Mean Difference: %.2f' % debug.smd(predict, 'sex', 'prediction', ' Male', ' Female'))

# %% [markdown]
# ## RACE

# %%
evaluate.get_confusion_matrix(predict,'actual','prediction', cutoff=best_cut)

# %%
race_levels = list(predict['race'].unique())
race_levels

# %% [markdown]
# #### Confusion Matrix for RACE = WHITE

# %%
white_cm = evaluate.get_confusion_matrix(predict,'actual','prediction', by='race', level=' White', cutoff=best_cut)
white_cm

# %% [markdown]
# #### Confusion Matrix for RACE = BLACK

# %%
black_cm = evaluate.get_confusion_matrix(predict,'actual','prediction', by='race', level=' Black', cutoff=best_cut)
black_cm

# %% [markdown]
# #### Confusion Matrix for RACE = ASIAN_PAC_ISLANDER

# %%
asian_pac_cm = evaluate.get_confusion_matrix(predict,'actual','prediction', by='race', level=' Asian-Pac-Islander', cutoff=best_cut)
asian_pac_cm

# %% [markdown]
# #### Confusion Matrix for RACE = AMER_INDIAN_ESKIMO

# %%
ame_indi_cm = evaluate.get_confusion_matrix(predict,'actual','prediction', by='race', level=' Amer-Indian-Eskimo', cutoff=best_cut)
ame_indi_cm

# %% [markdown]
# #### Confusion Matrix for RACE = OTHERS

# %%
others_cm = evaluate.get_confusion_matrix(predict,'actual','prediction', by='race', level=' Other', cutoff=best_cut)
others_cm

# %% [markdown]
# ### Disparate Accuracies and Errors for RACE

# %%
cm_dict_race = {'White': white_cm, 
                'Black': black_cm,
                'Asian Pacific Islander': asian_pac_cm,
                'American Idiana Eskimo': ame_indi_cm,
                'Others': others_cm} # group fairness metrics are based on confusion matrices
metrics_frame, disp_frame = debug.get_metrics_ratios(cm_dict_race, 'White') # calculate metrics and ratios
metrics_frame # display results

# %% [markdown]
# ### Calculate and Report Disparity

# %%
parity_threshold_low = 0.8    # user-defined low threshold value
parity_threshold_hi = 1.25   # user-defined high threshold value

#4/5 rule

# small utility function to format pandas table output
def disparate_red(val):
    
    color = 'blue' if (parity_threshold_low < val < parity_threshold_hi) else 'red'
    return 'color: %s' % color 

# display results
disp_frame.style.applymap(disparate_red)

# %% [markdown]
# ### Plot Prevalence Ratio Disparity for RACE

# %%
ax = disp_frame['Prevalence Ratio'].plot(kind='bar', color='b', title='Prevalence Ratio')
_ = ax.axhline(parity_threshold_low, color='r', linestyle='--')
_ = ax.axhline(parity_threshold_hi, color='r', linestyle='--')

# %% [markdown]
# ### Adverse Impact Ratio

# %%
print('Adverse impact ratio: %.3f' % debug.air(cm_dict_race, 'White', 'Black'))

# %%
print('Adverse impact ratio: %.3f' % debug.air(cm_dict_race, 'White', 'Others'))

# %%
print('Adverse impact ratio: %.3f' % debug.air(cm_dict_race, 'White', 'Asian Pacific Islander'))

# %% [markdown]
# ### Marginal Effect

# %%
print('Marginal effect: %.2f%%' % debug.marginal_effect(cm_dict_race, 'White', 'Black'))

# %%
print('Marginal effect: %.2f%%' % debug.marginal_effect(cm_dict_race, 'White', 'Others'))

# %% [markdown]
# ### Standardized Mean Difference

# %% [markdown]
# ' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo', ' Other'

# %%
print('Standardized Mean Difference: %.2f' % debug.smd(predict, 'race', 'prediction', ' White', ' Black' ))

# %%
print('Standardized Mean Difference: %.2f' % debug.smd(predict, 'race', 'prediction', ' White',' Amer-Indian-Eskimo' ))

# %%
print('Standardized Mean Difference: %.2f' % debug.smd(predict, 'race', 'prediction', ' White',' Other'))

# %% [markdown]
# # REMAINING

# %% [markdown]
# * ## TESTING AROUND THE YOUDEN CRITERIA POINT
# * ## DISPARATE ACCURACIES AND ERRORS

# %% [markdown]
# ## RESIDUAL ANALYSIS

# %%
xgb_pred = xgb_pred.as_data_frame() 
xgb_pred['xgb_yhat']=xgb_pred[" >50K"]

# %%
predict.columns

# %% [markdown]
# #### There are a lot NAN values in column 'prediction', not sure what's happening

# %%
predict['logloss'] = -predict['actual']*np.log(predict["prediction"]) -\
                       (1 - predict['actual'])*np.log(1 - predict["prediction"])

# %%
# initialize figure
fig, ax_ = plt.subplots(figsize=(8, 8))         

# plot groups with appropriate color
color_list = ['royalblue', 'magenta'] 
c_idx = 0
groups = predict.groupby("actual") # define groups for levels of PAY_0
for name, group in groups:
    ax_.plot(group.prediction, group.logloss, 
             label=' '.join(["actual", str(name)]),
             marker='o', linestyle='', color=color_list[c_idx], alpha=0.3)
    c_idx += 1

    # annotate plot
_ = plt.xlabel("prediction")
_ = plt.ylabel("logloss")
_ = ax_.legend(loc=1)
_ = plt.title('Global Logloss Residuals')

# %% [markdown]
# ### Race Groups

# %%
# use Seaborn FacetGrid for convenience
# some seaborn configs
sns.set(font_scale=0.9)                                         # legible font size
sns.set_style('whitegrid', {'axes.grid': False})                # white background, no grid in plots
sns.set_palette(sns.color_palette(["#4169e1", "#ff00ff"]))      # consistent colors

# facet grid of residuals by PAY_0 
sorted_ = predict.sort_values(by='race')                 # sort for better layout of by-groups
g = sns.FacetGrid(sorted_, col='race', hue="actual", col_wrap=4) # init grid
_ = g.map(plt.scatter, "prediction", "logloss", alpha=0.4)        # plot points
_ = g.add_legend(bbox_to_anchor=(0.82, 0.2))                    # legend

# %% [markdown]
# ### Sex Group

# %%
# use Seaborn FacetGrid for convenience
# some seaborn configs
sns.set(font_scale=0.9)                                         # legible font size
sns.set_style('whitegrid', {'axes.grid': False})                # white background, no grid in plots
sns.set_palette(sns.color_palette(["#4169e1", "#ff00ff"]))      # consistent colors

# facet grid of residuals by PAY_0 
sorted_ = predict.sort_values(by='sex')                 # sort for better layout of by-groups
g = sns.FacetGrid(sorted_, col='sex', hue="actual", col_wrap=4) # init grid
_ = g.map(plt.scatter, "prediction", "logloss", alpha=0.4)        # plot points
_ = g.add_legend(bbox_to_anchor=(0.82, 0.2))
